# %% [markdown]
# ## Imported functions from DataCleaning

# %% [markdown]
# ### TO-DO:
# - Try Word2Vec instead of TF-IDF
# - Flush out simple model to use KMeansClustering. Include hyperparamter optimization
# - Consider using a pre-trained GPT model
# - Evaluate model on training/validation data instead of randomly generated data

# %% [markdown]
# # Data Loading and Cleaning

# %%
import pandas as pd
import data_cleaning as dc

from nltk.stem import WordNetLemmatizer

# File paths
raw_data_path = './data/job_descriptions.csv'
preprocessed_data_path = raw_data_path.replace('.csv', '_preprocessed.csv')

lemmatizer = WordNetLemmatizer()

# Define desired database parameters. Set to -1 to load all data.
database_size = 15000

# Optionally force data to be regenerated
force_data_regeneration = False

try:
    # If force_data_regeneration is set, force an exception to reload the data
    if force_data_regeneration:
        print('Forcing data regeneration.')
        raise ValueError('Forcing data regeneration.')
    
    # Load the preprocessed data if it exists
    df = pd.read_csv(preprocessed_data_path)
    
    # If dataframe is not expected size, reload the data
    if database_size != -1 and len(df) > database_size:
        df = df.sample(n=database_size)
    elif database_size != -1 and len(df) < database_size:    
        print('Preprocessed file is not the expected size. Reloading data.')
        raise ValueError('Preprocessed file is not the expected size.')
    
    print('Preprocessed file found and loaded.')
except (FileNotFoundError, ValueError):
    # Load dataset with stock data
    df = pd.read_csv(raw_data_path)

    # Clean the text data
    print('Cleaning text data...')
    df['Preprocessed Job Description'] = df['Job Description'].apply(lambda x: dc.preprocess_document(x, lemmatizer))
    df['Preprocessed Responsibilities'] = df['Responsibilities'].apply(lambda x: dc.preprocess_document(x, lemmatizer))
        
    # Save the preprocessed data
    df.drop_duplicates(inplace=True)
    df.to_csv(preprocessed_data_path, index=False)
    print('File preprocessing completed and saved.')
# Out:
# Preprocessed file found and loaded.

# %%
import text_embedding as te
import importlib
importlib.reload(dc)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import MultiLabelBinarizer
from gensim.models import KeyedVectors

# Define feature columns
text_features = ['Preprocessed Job Description', 'Preprocessed Responsibilities']
categorical_features = ['Qualifications', 'Job Title']
numerical_features = ['Company Size']

# Define target columns
target_columns = ['skills']

# Remove all unused columns
df = df[text_features + categorical_features + numerical_features + target_columns]

# Preprocess the categorical data
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
categorical_transformer.fit(df[categorical_features])

# Preprocess the numerical data
scaler = StandardScaler()
numerical_transformer = scaler.fit(df[['Company Size']])

# Prepare the text vectorizers
word_vectors = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=5, 
                                  max_features=5000, 
                                  ngram_range=(1, 3))
tfidf_vectorizer.fit(df['Preprocessed Job Description'])
# Out:
# TfidfVectorizer(max_df=0.95, max_features=5000, min_df=5, ngram_range=(1, 3))

# %%
from sklearn.model_selection import train_test_split

# Prepare the two feature matrices
word2Vec_X = te.embed_w2v_dataframe(df, word_vectors, categorical_transformer, numerical_transformer, categorical_features, numerical_features)
tfidf_X = dc.prepare_dataset(df, tfidf_vectorizer, categorical_transformer, numerical_transformer, text_features, categorical_features, numerical_features)

# Itemize the skills in the skills columns
df['skills'] = df['skills'].apply(dc.preprocess_skills)
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(df['skills'])

# Split the dataset into training and testing sets (80% train, 20% test)
X_w2v_train, X_w2v_test, y_train, y_test = train_test_split(word2Vec_X, y, test_size=0.2, random_state=42)
X_tfidf_train, X_tfidf_test, y_train, y_test = train_test_split(tfidf_X, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Model Definition & Tuning

# %%
import model_util as mu
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier

# Define the parameter grid for w2v_model
w2v_param_grid = {
    'estimator__n_estimators': [50, 100, 200],
    'estimator__max_depth': [None, 5, 10, 15],
}

# Define the parameter grid for tfidf_model
tfidf_param_grid = {
    'estimator__n_estimators': [50, 100, 200],
    'estimator__max_depth': [None, 5, 10, 15],
}

# Prepare model loading parameters
scoring_metric = 'f1_samples'
folds = 3
force_reload = False
w2v_model = OneVsRestClassifier(RandomForestClassifier(n_estimators=100, random_state=42))
tfidf_model = OneVsRestClassifier(RandomForestClassifier(n_estimators=100, random_state=42))

# Load the models from disk if they exist, otherwise train new models
w2v_model = mu.load_model(w2v_model, './models/w2v_model.pkl', w2v_param_grid, X_w2v_train, y_train, scoring_metric, folds, force_reload)
tfidf_model = mu.load_model(tfidf_model, './models/tfidf_model.pkl', tfidf_param_grid, X_tfidf_train, y_train, scoring_metric, folds, force_reload)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time=19.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time=19.9min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time=20.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=38.4min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=38.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=38.6min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time=19.5min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time=19.5min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time=27.1min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=186.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=186.0min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=164.3min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=164.5min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=164.6min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time=52.2min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=218.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time=37.1min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time=37.2min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=224.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=62.0min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=237.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=65.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=65.2min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time=41.3min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=141.0min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time=28.5min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time=28.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=124.9min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=61.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=125.1min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=67.0min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=75.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=139.7min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=109.9min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=109.5min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=97.6min
# KNN Model trained and saved to disk.
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time= 4.4min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time= 4.4min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time= 4.4min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time= 4.0min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time= 4.1min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 8.6min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 8.6min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time= 8.7min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time= 4.1min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time= 9.9min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=10.1min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=10.1min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=19.6min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=20.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time= 7.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time= 7.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time= 7.7min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=23.4min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=23.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=13.6min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=23.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=11.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=10.9min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time= 4.6min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=21.6min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time= 4.5min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time= 4.5min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=10.6min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=21.2min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=20.9min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=11.0min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=11.7min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=20.8min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=17.4min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=16.8min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=12.9min
# KNN Model trained and saved to disk.

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import classification_report

# Predict on the test data
y_w2v_pred = w2v_model.predict(X_w2v_test)
y_tfidf_pred = tfidf_model.predict(X_tfidf_test)

# Additional detailed performance analysis
print("Word2Vec Classification Report:")
print(classification_report(y_test, y_w2v_pred, target_names=mlb.classes_))
print("\nTF-IDF Classification Report:")
print(classification_report(y_test, y_tfidf_pred, target_names=mlb.classes_))
# Out:
# Word2Vec Classification Report:
#                                                              precision    recall  f1-score   support
#
#                                                 A/B testing       1.00      1.00      1.00        19
#                                A/B testing and optimization       1.00      1.00      1.00         4
#                                                        AJAX       1.00      1.00      1.00         7
#                                  API design and development       1.00      1.00      1.00        11
#                                             API development       1.00      1.00      1.00        27
#                             Brand positioning and messaging       1.00      1.00      1.00         8
#                                             Brand promotion       1.00      1.00      1.00         6
#                                          Brand storytelling       1.00      1.00      1.00        22
#                                              Brand strategy       1.00      1.00      1.00         7
#                                  Brand strategy development       1.00      1.00      1.00        12
#                              Branding and theme integration       1.00      1.00      1.00        10
#                       Branding and visual identity creation       1.00      1.00      1.00         9
#                                               Bridge design       1.00      1.00      1.00         7
#                                           Budget management       1.00      1.00      1.00        60
#                                             Budget planning       1.00      1.00      1.00         4
#                                                   Budgeting       1.00      1.00      1.00        26
#                                  Budgeting and cost control       1.00      1.00      1.00        13
#                              Budgeting and expense tracking       1.00      1.00      1.00        21
#                            Budgeting and financial analysis       1.00      1.00      1.00         5
#                          Budgeting and financial management       1.00      1.00      1.00        15
#                                  Bug tracking and reporting       1.00      1.00      1.00        27
#                                              Building codes       1.00      1.00      1.00         5
#                  Building codes and regulations 3D modeling       1.00      1.00      1.00         8
#                    Building codes and regulations knowledge       1.00      1.00      1.00        20
#                                Building codes and standards       1.00      1.00      1.00        13
#                                            Building systems       1.00      1.00      1.00         3
#                                             Business acumen       1.00      1.00      1.00        23
#                                        Business development       1.00      1.00      1.00        22
#                              Business intelligence concepts       1.00      1.00      1.00        20
#                                   Business process analysis       1.00      1.00      1.00         6
#                                           Business strategy       1.00      1.00      1.00         9
#                                 Business strategy alignment       1.00      1.00      1.00         7
#                                   Business systems analysis       1.00      1.00      1.00         6
#                                  Business tax law knowledge       1.00      1.00      1.00         7
#                       Business-to-business sales strategies       1.00      1.00      1.00         7
#                                         CAD and 3D modeling       1.00      1.00      1.00         6
#                                     CAD and design software       1.00      1.00      1.00         6
#                                                CAD software       1.00      1.00      1.00        14
#                                    CAD software proficiency       1.00      1.00      1.00         8
#                                CAD/CAM software proficiency       1.00      1.00      1.00        10
#                                             CRM integration       1.00      1.00      1.00         7
#                                                CRM software       1.00      1.00      1.00        11
#                                          CRM software usage       1.00      1.00      1.00         7
#                                                         CSS       1.00      1.00      1.00         6
#                                       CSS for accessibility       1.00      1.00      1.00        10
#                                                        CSS,       1.00      1.00      1.00        17
#                                                    CSS, and       1.00      1.00      1.00        16
#                         Calendar and appointment management       1.00      1.00      1.00        17
#                                      Calendar and docketing       1.00      1.00      1.00         7
#                                         Calendar management       1.00      1.00      1.00        30
#                                      Call center operations       1.00      1.00      1.00         9
#                                          Campaign analytics       1.00      1.00      1.00         5
#                           Campaign effectiveness evaluation       1.00      1.00      1.00         9
#                                       Campaign optimization       1.00      1.00      1.00        11
#                                         Candidate screening       1.00      1.00      1.00         6
#                                            Canonicalization       1.00      1.00      1.00        18
#                                           Capacity planning       1.00      1.00      1.00        16
#                     Care coordination with healthcare teams       1.00      1.00      1.00         9
#                                               Care planning       1.00      1.00      1.00         6
#                                             Case management       1.00      1.00      1.00        23
#                                            Case preparation       1.00      1.00      1.00        14
#                                          Cash flow analysis       1.00      1.00      1.00        10
#                                               Cash handling       1.00      1.00      1.00        11
#                                  Catering and menu planning       1.00      1.00      1.00        14
#                                         Customer engagement       1.00      1.00      1.00         7
#                                  Customer experience design       1.00      1.00      1.00        10
#                                Customer experience strategy       1.00      1.00      1.00         6
#                                  Customer feedback analysis       1.00      1.00      1.00        11
#                                    Customer journey mapping       1.00      1.00      1.00         6
#                            Customer relationship management       1.00      1.00      1.00        37
#                                       Customer satisfaction       1.00      1.00      1.00         8
#                                            Customer service       1.00      1.00      1.00        57
#                          Customer service and communication       1.00      1.00      1.00         4
#                                     Customer service skills       1.00      1.00      1.00        11
#                                            Customer support       1.00      1.00      1.00         8
#                                      Customer support tools       1.00      1.00      1.00         8
#                                               Cybersecurity       1.00      1.00      1.00        14
#                           Cybersecurity and risk management       1.00      1.00      1.00         5
#                                     Cybersecurity knowledge       1.00      1.00      1.00         4
#                                            DOM manipulation       1.00      1.00      1.00         7
#                                               Data analysis       1.00      1.00      1.00       226
#                               Data analysis and forecasting       1.00      1.00      1.00        10
#                            Data analysis and interpretation       1.00      1.00      1.00         8
#                                 Data analysis and reporting       1.00      1.00      1.00        17
#                       Data analysis and visualization tools       1.00      1.00      1.00        20
#                                    Data analysis techniques       1.00      1.00      1.00         5
#                                         Data analysis tools       1.00      1.00      1.00        32
#                                              Data analytics       1.00      1.00      1.00         7
#                                    Data architecture design       1.00      1.00      1.00         6
#                           Data cleansing and transformation       1.00      1.00      1.00        23
#                                Data collection and analysis       1.00      1.00      1.00        56
#                          Data collection and interpretation       1.00      1.00      1.00         5
#                               Data collection and reporting       1.00      1.00      1.00         9
#                          Data encryption and access control       1.00      1.00      1.00         6
#                                                  Data entry       1.00      1.00      1.00         8
#                               Data entry accuracy and speed       1.00      1.00      1.00        19
#                                    Data entry and retrieval       1.00      1.00      1.00         3
#                                  Data governance principles       1.00      1.00      1.00        11
#                                            Data integration       1.00      1.00      1.00        12
#                                         Data interpretation       1.00      1.00      1.00        14
#                                                Data mapping       1.00      1.00      1.00         9
#                                              Data migration       1.00      1.00      1.00         9
#                                               Data modeling       1.00      1.00      1.00        63
#                                 Data modeling and reporting       1.00      1.00      1.00        20
#                                          Data preprocessing       1.00      1.00      1.00         7
#                             Data preprocessing and cleaning       1.00      1.00      1.00        18
#                                Data processing and analysis       1.00      1.00      1.00         4
#                               Data profiling and validation       1.00      1.00      1.00        11
#                     Data quality assessment and improvement       1.00      1.00      1.00        11
#                                      Data quality assurance       1.00      1.00      1.00         6
#                                               Data security       1.00      1.00      1.00        12
#             Data security and privacy regulations knowledge       1.00      1.00      1.00         6
#                                                  Data tools       1.00      1.00      1.00        10
#                                           Data verification       1.00      1.00      1.00        19
#                                          Data visualization       1.00      1.00      1.00        53
#                                    Data visualization tools       1.00      1.00      1.00        28
#                                            Data warehousing       1.00      1.00      1.00         6
#                                 Data-driven decision-making       1.00      1.00      1.00        25
#                            Database auditing and monitoring       1.00      1.00      1.00         6
#                                             Database design       1.00      1.00      1.00         9
#                             Database design and development       1.00      1.00      1.00         6
#                                        Database integration       1.00      1.00      1.00        13
#                                        Database maintenance       1.00      1.00      1.00         9
#                                         Database management       1.00      1.00      1.00        41
#                                 Database management systems       1.00      1.00      1.00        18
#                             Database querying and reporting       1.00      1.00      1.00         6
#                                  Database security measures       1.00      1.00      1.00         6
#                                           Database software       1.00      1.00      1.00        19
#                            Database tuning and optimization       1.00      1.00      1.00        12
#                               Debugging and troubleshooting       1.00      1.00      1.00        12
#                             Decor selection and arrangement       1.00      1.00      1.00         6
#                                            Deed preparation       1.00      1.00      1.00        10
#                                               Deep learning       1.00      1.00      1.00         7
#                               Defect reporting and tracking       1.00      1.00      1.00         3
#                                             Defect tracking       1.00      1.00      1.00         5
#                             Deliverability metrics analysis       1.00      1.00      1.00         6
#                                          Demand forecasting       1.00      1.00      1.00        37
#                                        Demonstrating skills       1.00      1.00      1.00         7
#                              Dental health program planning       1.00      1.00      1.00         1
#                                    Dental hygiene knowledge       1.00      1.00      1.00         9
#                                      Dental instrumentation       1.00      1.00      1.00         8
#                             Dental public health principles       1.00      1.00      1.00         1
#                                        Dentistry for horses       1.00      1.00      1.00         6
#                                                  Deployment       1.00      1.00      1.00         6
#                                      Deposition preparation       1.00      1.00      1.00        10
#                                         Design coordination       1.00      1.00      1.00         3
#                                             Design thinking       1.00      1.00      1.00         9
#                                           Design tools like       1.00      1.00      1.00        10
#               Desktop hardware and software troubleshooting       1.00      1.00      1.00         6
#                                             Detail-oriented       1.00      1.00      1.00         5
#                                            DevOps practices       1.00      1.00      1.00         7
#                                   Developmental assessments       1.00      1.00      1.00         7
#                                    Developmental milestones       1.00      1.00      1.00         6
#                                     Diagnosis and treatment       1.00      1.00      1.00         6
#                                           Diagnostic skills       1.00      1.00      1.00         8
#                                            Diagnostic tests       1.00      1.00      1.00         5
#                                  Differentiated instruction       1.00      1.00      1.00         8
#                                    Digital marketing skills       1.00      1.00      1.00        10
#                                Digital marketing strategies       1.00      1.00      1.00        16
#                                  Digital marketing strategy       1.00      1.00      1.00        19
#                      Digital marketing strategy development       1.00      1.00      1.00         5
#                                                   Directory       1.00      1.00      1.00        11
#                                           Disaster recovery       1.00      1.00      1.00         7
#                                  Disaster recovery planning       1.00      1.00      1.00         7
#                                        Discovery management       1.00      1.00      1.00         4
#                              Discretion and confidentiality       1.00      1.00      1.00        17
#                                          Dispute resolution       1.00      1.00      1.00        13
#                                       Distributed computing       1.00      1.00      1.00         4
#                                         Distributed systems       1.00      1.00      1.00         9
#                         Diversity and inclusion initiatives       1.00      1.00      1.00         9
#                                         Divorce proceedings       1.00      1.00      1.00        12
#                                           Document drafting       1.00      1.00      1.00        24
#                                         Document management       1.00      1.00      1.00        15
#                                             Document review       1.00      1.00      1.00         4
# ...
#                                                   Technical       1.00      1.00      1.00        18
#                                      Technical architecture       1.00      1.00      1.00         5
#                                        Technical background       1.00      1.00      1.00         5
#                                     Technical documentation       1.00      1.00      1.00         8
#                                           Technical drawing       1.00      1.00      1.00         3
#                                         Technical expertise       1.00      1.00      1.00         6
#                                         Technical knowledge       1.00      1.00      1.00        61
#                                       Technical proficiency       1.00      1.00      1.00         5
#                                    Technical specifications       1.00      1.00      1.00         6
#                                   Technical troubleshooting       1.00      1.00      1.00        21
#                                           Technical writing       1.00      1.00      1.00        13
#                                      Technology proficiency       1.00      1.00      1.00        37
#                                        Territory management       1.00      1.00      1.00        21
#                                             Test automation       1.00      1.00      1.00        14
#                        Test automation frameworks and tools       1.00      1.00      1.00         1
#                                       Test automation tools       1.00      1.00      1.00        21
#                                            Test case design       1.00      1.00      1.00         5
#                              Test case design and execution       1.00      1.00      1.00         3
#                                       Test case development       1.00      1.00      1.00        27
#                                        Test data management       1.00      1.00      1.00        18
#                       Test environment setup and management       1.00      1.00      1.00         1
#                                              Test execution       1.00      1.00      1.00         5
#                                  Test framework development       1.00      1.00      1.00        27
#                                               Test planning       1.00      1.00      1.00         5
#                                  Test planning and strategy       1.00      1.00      1.00         3
#                                              Test reporting       1.00      1.00      1.00         9
#                                              Test scenarios       1.00      1.00      1.00         6
#                                     Test script development       1.00      1.00      1.00         6
#                     Test script development and maintenance       1.00      1.00      1.00         1
#                                 Testing and experimentation       1.00      1.00      1.00         6
#                                      Testing and validation       1.00      1.00      1.00         2
#                                       Testing methodologies       1.00      1.00      1.00        27
#                                            Therapy planning       1.00      1.00      1.00        12
#                                            Threat detection       1.00      1.00      1.00         6
#                                           Ticket management       1.00      1.00      1.00         8
#                                           Ticket resolution       1.00      1.00      1.00         5
#                                      Ticketing system usage       1.00      1.00      1.00        20
#                                             Time management       1.00      1.00      1.00        62
#                             Timeline and logistics planning       1.00      1.00      1.00        16
#                                           Timeline planning       1.00      1.00      1.00         4
#                                              Title searches       1.00      1.00      1.00        10
#                                    Trademark and patent law       1.00      1.00      1.00         2
#                               Traffic analysis and planning       1.00      1.00      1.00         3
#                                         Traffic engineering       1.00      1.00      1.00         7
#                                    Training and development       1.00      1.00      1.00        25
#                               Training material development       1.00      1.00      1.00        11
#                               Training program coordination       1.00      1.00      1.00        11
#                                Training program development       1.00      1.00      1.00         7
#                                               Transcription       1.00      1.00      1.00         7
#                                            Transfer pricing       1.00      1.00      1.00         3
#                              Transfer pricing documentation       1.00      1.00      1.00         3
#                                  Transportation engineering       1.00      1.00      1.00         3
#                                    Transportation logistics       1.00      1.00      1.00        10
#                                     Transportation planning       1.00      1.00      1.00        14
#                                           Trauma management       1.00      1.00      1.00        10
#                                        Trauma-informed care       1.00      1.00      1.00         6
#                                         Travel coordination       1.00      1.00      1.00        31
#                                         Treasury management       1.00      1.00      1.00        10
#                                          Treatment planning       1.00      1.00      1.00        13
#                                              Trend analysis       1.00      1.00      1.00        15
#                                        Trend identification       1.00      1.00      1.00        17
#                                       Triage and assessment       1.00      1.00      1.00        10
#                                               Trial support       1.00      1.00      1.00        14
#                                             Troubleshooting       1.00      1.00      1.00        81
#                             Troubleshooting and diagnostics       1.00      1.00      1.00         9
#                       Troubleshooting deliverability issues       1.00      1.00      1.00         6
#                     Troubleshooting wireless network issues       1.00      1.00      1.00         6
#                                                  Typography       1.00      1.00      1.00        19
#                                 Typography and color theory       1.00      1.00      1.00        21
#                     UI design principles and best practices       1.00      1.00      1.00        21
#                                                UI/UX design       1.00      1.00      1.00         4
#                                    UI/UX design 3D modeling       1.00      1.00      1.00         6
#                                                UX/UI design       1.00      1.00      1.00         8
#                                          UX/UI design tools       1.00      1.00      1.00        26
#                     Understanding of healthcare regulations       1.00      1.00      1.00         7
#                                   Urban design and planning       1.00      1.00      1.00         6
#                                              Urban planning       1.00      1.00      1.00         3
#                                        Usability evaluation       1.00      1.00      1.00         3
#                                           Usability testing       1.00      1.00      1.00        34
#                         Usability testing and user research       1.00      1.00      1.00        26
#                      Usability testing tools and techniques       1.00      1.00      1.00         3
#        Usability testing with individuals with disabilities       1.00      1.00      1.00        10
#                                         User authentication       1.00      1.00      1.00         6
#                                User behavior and psychology       1.00      1.00      1.00        25
#                                             User experience       1.00      1.00      1.00         5
#                                      User experience design       1.00      1.00      1.00        26
#                           User experience for accessibility       1.00      1.00      1.00        10
#                                    User experience strategy       1.00      1.00      1.00         9
#                                   User interface assessment       1.00      1.00      1.00         3
#                                       User interface design       1.00      1.00      1.00        54
#                                   User interface principles       1.00      1.00      1.00         6
#                                        User journey mapping       1.00      1.00      1.00         9
#                                                User manuals       1.00      1.00      1.00        12
#                                               User research       1.00      1.00      1.00        16
#                                       User research methods       1.00      1.00      1.00         8
#                                          User story writing       1.00      1.00      1.00         9
#                                                User testing       1.00      1.00      1.00        13
#                             User-centered design principles       1.00      1.00      1.00        26
#                                        Valuation techniques       1.00      1.00      1.00         6
#                                Vendor and sponsor relations       1.00      1.00      1.00         4
#                               Vendor and supplier relations       1.00      1.00      1.00        21
#                                           Vendor assessment       1.00      1.00      1.00        28
#                                        Vendor communication       1.00      1.00      1.00        10
#                                         Vendor coordination       1.00      1.00      1.00        43
#                                           Vendor management       1.00      1.00      1.00        34
#                                          Vendor negotiation       1.00      1.00      1.00        16
#                              Vendor outreach and engagement       1.00      1.00      1.00         9
#                                            Vendor relations       1.00      1.00      1.00        18
#                                             Venue selection       1.00      1.00      1.00        14
#                              Venue selection and management       1.00      1.00      1.00        16
#                                             Version control       1.00      1.00      1.00        22
#                                         Veterinary medicine       1.00      1.00      1.00         5
#                                 Virtualization technologies       1.00      1.00      1.00         7
#                                        Visual communication       1.00      1.00      1.00        10
#                                               Visual design       1.00      1.00      1.00         7
#                                    Visual design and layout       1.00      1.00      1.00        21
#                                               Visualization       1.00      1.00      1.00         8
#                                                      Vue.js       1.00      1.00      1.00        16
#                                    Vulnerability assessment       1.00      1.00      1.00        22
#            Vulnerability assessment and penetration testing       1.00      1.00      1.00         6
#                                      Vulnerability scanning       1.00      1.00      1.00         5
#                                        Warehouse management       1.00      1.00      1.00         9
#                                          Water conservation       1.00      1.00      1.00         5
#                            Water resource modeling software       1.00      1.00      1.00        17
#                                 Water resources engineering       1.00      1.00      1.00        17
#                                     Waterfall methodologies       1.00      1.00      1.00         5
#                                        Watershed management       1.00      1.00      1.00        17
#                                           Wealth management       1.00      1.00      1.00         5
#                                Wealth management strategies       1.00      1.00      1.00         5
#                                 Web accessibility standards       1.00      1.00      1.00        10
#                                               Web analytics       1.00      1.00      1.00         7
#                                 Web application development       1.00      1.00      1.00         6
#                                         Web design concepts       1.00      1.00      1.00         6
#                                       Web design principles       1.00      1.00      1.00        11
#                                Web performance optimization       1.00      1.00      1.00        12
#                                              Website audits       1.00      1.00      1.00        13
#                                      Website crawl analysis       1.00      1.00      1.00         5
#                                     Wedding design concepts       1.00      1.00      1.00         6
#                                           Wedding etiquette       1.00      1.00      1.00        18
#                                            Wedding planning       1.00      1.00      1.00        25
#                               Wi-Fi standards and protocols       1.00      1.00      1.00         6
#                                 Wireframing and prototyping       1.00      1.00      1.00        40
#                           Wireframing and prototyping tools       1.00      1.00      1.00        34
#                    Wireless network design and architecture       1.00      1.00      1.00         6
#                                         Wireless networking       1.00      1.00      1.00         9
#                                 Wireless security protocols       1.00      1.00      1.00         6
#                                         Workflow automation       1.00      1.00      1.00         7
#                                             Workflow design       1.00      1.00      1.00         5
#                Workplace discrimination and harassment laws       1.00      1.00      1.00         4
#                                        Workplace ergonomics       1.00      1.00      1.00         7
#                                    Writing research reports       1.00      1.00      1.00        15
#                                              Writing skills       1.00      1.00      1.00        15
#                                                XML sitemaps       1.00      1.00      1.00        18
#                                          Zoning regulations       1.00      1.00      1.00         9
#
#                                                   micro avg       1.00      1.00      1.00     17892
#                                                   macro avg       1.00      1.00      1.00     17892
#                                                weighted avg       1.00      1.00      1.00     17892
#                                                 samples avg       1.00      1.00      1.00     17892

# %% [markdown]
# ## Custom Exampels

# %%
importlib.reload(dc)
importlib.reload(dc)

# Define a sample datapoint
data = {
    'Job Description': 'As a staff member of the Compute Infrastructure team at LinkedIn, you will be charged with building the next-generation infrastructure and platforms for LinkedIn.',
    'Responsibilities': 'Develop predictive models to solve business problems',
    'Qualifications': 'PhD',
    'Work Type': 'Full-Time',
    'Preference': 'Male',
    'Job Title': 'Data Scientist',
    'Role': 'Data Scientist',
    'Company Size': 33428,
}
sample_df = pd.DataFrame([data])
sample_df['Preprocessed Job Description'] = sample_df['Job Description'].apply(lambda x: dc.preprocess_document(x, lemmatizer))
sample_df['Preprocessed Responsibilities'] = sample_df['Responsibilities'].apply(lambda x: dc.preprocess_document(x, lemmatizer))

sample_tfidf_X = dc.prepare_dataset(sample_df, tfidf_vectorizer, categorical_transformer, numerical_transformer, text_features, categorical_features, numerical_features)
sample_w2v_X = te.embed_w2v_dataframe(sample_df, word_vectors, categorical_transformer, numerical_transformer, categorical_features, numerical_features)

# %%
# Predict the skills required for the sample datapoint
y_sample_pred_w2v = w2v_model.predict(sample_w2v_X)
y_sample_pred_tfidf = tfidf_model.predict(sample_tfidf_X)

# Convert the predicted skills back to their original labels
w2v_pred_skills = mlb.inverse_transform(y_sample_pred_w2v)
tfidf_pred_skills = mlb.inverse_transform(y_sample_pred_tfidf)
print("Word2Vec Predicted Skills:", w2v_pred_skills)
print("TF-IDF Predicted Skills:", tfidf_pred_skills)
# Out:
# Word2Vec Predicted Skills: [()]
# TF-IDF Predicted Skills: [()]
