# %% [markdown]
# # Data Loading and Cleaning

# %%
import pandas as pd
import code_util.data_cleaning as dc
import importlib

from nltk.stem import WordNetLemmatizer

# File paths
raw_data_path = './data/job_descriptions_20k.csv'
preprocessed_data_path = raw_data_path.replace('.csv', '_preprocessed.csv')

lemmatizer = WordNetLemmatizer()

# Define desired database parameters. Set to -1 to load all data.
database_size = -1

# Optionally force data to be regenerated
force_data_regeneration = False

try:
    # If force_data_regeneration is set, force an exception to reload the data
    if force_data_regeneration:
        print('Forcing data regeneration.')
        raise ValueError('Forcing data regeneration.')
    
    # Load the preprocessed data if it exists
    df = pd.read_csv(preprocessed_data_path)
    
    # If dataframe is not expected size, reload the data
    if database_size != -1 and len(df) > database_size:
        df = df.sample(n=database_size)
    elif database_size != -1 and len(df) < database_size:    
        print('Preprocessed file is not the expected size. Reloading data.')
        raise ValueError('Preprocessed file is not the expected size.')
    
    print('Preprocessed file found and loaded.')
except (FileNotFoundError, ValueError):
    # Load dataset with stock data
    df = pd.read_csv(raw_data_path)

    # Clean the text data
    print('Cleaning text data...')
    df['Preprocessed Job Description'] = df['Job Description'].apply(lambda x: dc.preprocess_document(x, lemmatizer))
    df['Preprocessed Responsibilities'] = df['Responsibilities'].apply(lambda x: dc.preprocess_document(x, lemmatizer))
        
    # Save the preprocessed data
    df.drop_duplicates(inplace=True)
    df.to_csv(preprocessed_data_path, index=False)
    print('File preprocessing completed and saved.')
# Out:
# Preprocessed file found and loaded.

# %%
import code_util.text_embedding as te
importlib.reload(dc)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.preprocessing import MultiLabelBinarizer
from gensim.models import KeyedVectors

# Define feature columns
text_features = ['Preprocessed Job Description', 'Preprocessed Responsibilities']
categorical_features = ['Qualifications', 'Job Title']
numerical_features = ['Company Size']

# Define target columns
target_columns = ['skills']

# Remove all unused columns
df = df[text_features + categorical_features + numerical_features + target_columns]

# Preprocess the categorical data
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
categorical_transformer.fit(df[categorical_features])

# Preprocess the numerical data
scaler = StandardScaler()
numerical_transformer = scaler.fit(df[['Company Size']])

# Prepare the text vectorizers
word_vectors = KeyedVectors.load_word2vec_format('./models/GoogleNews-vectors-negative300.bin', binary=True)
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=5, 
                                  max_features=5000, 
                                  ngram_range=(1, 3))
tfidf_vectorizer.fit(df['Preprocessed Job Description'])
# Out:
# TfidfVectorizer(max_df=0.95, max_features=5000, min_df=5, ngram_range=(1, 3))

# %%
from sklearn.model_selection import train_test_split
importlib.reload(te)
importlib.reload(dc)

# Prepare the two feature matrices
word2Vec_X = te.embed_w2v_dataframe(df, word_vectors, categorical_transformer, scaler, categorical_features, numerical_features)
tfidf_X = dc.prepare_dataset(df, tfidf_vectorizer, categorical_transformer, scaler, text_features, categorical_features, numerical_features)

# Itemize the skills in the skills columns
df['skills'] = df['skills'].apply(dc.preprocess_skills)
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(df['skills'])

# Split the dataset into training and testing sets (80% train, 20% test)
X_w2v_train, X_w2v_test, y_train, y_test = train_test_split(word2Vec_X, y, test_size=0.2, random_state=42)
X_tfidf_train, X_tfidf_test, y_train, y_test = train_test_split(tfidf_X, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Model Definition & Tuning

# %%
import code_util.model_util as mu
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier

# Define the parameter grid for w2v_model
w2v_param_grid = {
    'estimator__n_estimators': [50, 100, 200],
    'estimator__max_depth': [None, 5, 10, 15],
}

# Define the parameter grid for tfidf_model
tfidf_param_grid = {
    'estimator__n_estimators': [50, 100, 200],
    'estimator__max_depth': [None, 5, 10, 15],
}

# Prepare model loading parameters
scoring_metric = 'f1_micro'
folds = 3
force_reload = False
w2v_model = OneVsRestClassifier(RandomForestClassifier(n_estimators=100, random_state=42),
                                verbose = -1)
tfidf_model = OneVsRestClassifier(RandomForestClassifier(n_estimators=100, random_state=42),
                                  verbose = -1)

# Load the models from disk if they exist, otherwise train new models
w2v_model = mu.load_model(w2v_model, './models/w2v_model.pkl', w2v_param_grid, X_w2v_train, y_train, scoring_metric, folds, force_reload)
tfidf_model = mu.load_model(tfidf_model, './models/tfidf_model.pkl', tfidf_param_grid, X_tfidf_train, y_train, scoring_metric, folds, force_reload)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time=64.7min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time=64.8min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time=64.8min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=162.2min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=162.2min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=162.3min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time=98.9min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time=99.0min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time=26.3min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=219.6min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=220.0min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=59.0min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=59.1min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time=59.8min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time=34.4min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=190.3min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time=34.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time=34.6min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=124.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=67.5min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=130.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=67.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=66.7min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time=33.5min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=123.2min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time=28.1min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time=28.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=119.6min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=119.9min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=55.2min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=55.0min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=80.0min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=138.0min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=132.3min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=131.3min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=121.4min
# Best Parameters: {'estimator__max_depth': None, 'estimator__n_estimators': 50}
# Model trained and saved to disk.
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time= 5.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time= 5.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=50; total time= 5.0min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time= 4.6min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time= 4.7min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=10.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=10.0min
# [CV] END estimator__max_depth=None, estimator__n_estimators=100; total time=10.1min
# [CV] END .estimator__max_depth=5, estimator__n_estimators=50; total time= 4.8min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time= 9.1min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time= 9.4min
# [CV] END estimator__max_depth=5, estimator__n_estimators=100; total time= 9.3min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=19.5min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=19.5min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time= 8.6min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time= 8.7min
# [CV] END estimator__max_depth=10, estimator__n_estimators=50; total time= 8.6min
# [CV] END estimator__max_depth=None, estimator__n_estimators=200; total time=23.8min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=31.1min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=23.8min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=32.2min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=20.6min
# [CV] END estimator__max_depth=10, estimator__n_estimators=100; total time=20.8min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time= 5.3min
# [CV] END estimator__max_depth=5, estimator__n_estimators=200; total time=32.1min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time= 5.5min
# [CV] END estimator__max_depth=15, estimator__n_estimators=50; total time= 5.7min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=30.4min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=30.2min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=10.7min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time=10.6min
# [CV] END estimator__max_depth=15, estimator__n_estimators=100; total time= 9.9min
# [CV] END estimator__max_depth=10, estimator__n_estimators=200; total time=20.3min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=22.0min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=23.2min
# [CV] END estimator__max_depth=15, estimator__n_estimators=200; total time=21.3min
# Best Parameters: {'estimator__max_depth': None, 'estimator__n_estimators': 50}
# Model trained and saved to disk.

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import classification_report

# Predict on the test data
y_w2v_pred = w2v_model.predict(X_w2v_test)
y_tfidf_pred = tfidf_model.predict(X_tfidf_test)

# Additional detailed performance analysis
print("Word2Vec Classification Report:")
print(classification_report(y_test, y_w2v_pred, target_names=mlb.classes_))
print("\nTF-IDF Classification Report:")
print(classification_report(y_test, y_tfidf_pred, target_names=mlb.classes_))
# Out:
# Word2Vec Classification Report:
#                                                              precision    recall  f1-score   support
#
#                                                 A/B testing       1.00      1.00      1.00        29
#                                A/B testing and optimization       1.00      1.00      1.00         6
#                                                        AJAX       1.00      1.00      1.00         7
#                                  API design and development       1.00      1.00      1.00         9
#                                             API development       1.00      1.00      1.00        35
#                                             API integration       1.00      1.00      1.00        12
#                                               API knowledge       1.00      1.00      1.00        16
#                                                        APIs       1.00      1.00      1.00         8
#                           APIs and web services integration       1.00      1.00      1.00         7
#                                                        ARIA       1.00      1.00      1.00        12
#                                     Accessibility standards       1.00      1.00      1.00         3
#                                 Accessibility testing tools       1.00      1.00      1.00        12
#                                  Budgeting and cost control       1.00      1.00      1.00         7
#                              Budgeting and expense tracking       1.00      1.00      1.00        24
#                            Budgeting and financial analysis       1.00      1.00      1.00        13
#                          Budgeting and financial management       1.00      1.00      1.00        34
#                                  Bug tracking and reporting       1.00      1.00      1.00        21
#                                              Building codes       1.00      1.00      1.00         7
#                  Building codes and regulations 3D modeling       1.00      1.00      1.00        11
#                    Building codes and regulations knowledge       1.00      1.00      1.00        16
#                                Building codes and standards       1.00      1.00      1.00         5
#                                            Building systems       1.00      1.00      1.00         5
#                                             Business acumen       1.00      1.00      1.00        26
#                                        Business development       1.00      1.00      1.00        40
#                              Business intelligence concepts       1.00      1.00      1.00        14
#                                   Business process analysis       1.00      1.00      1.00        13
#                                           Business strategy       1.00      1.00      1.00         5
#                                 Business strategy alignment       1.00      1.00      1.00         5
#                                   Business systems analysis       1.00      1.00      1.00         7
#                                  Business tax law knowledge       1.00      1.00      1.00         8
#                       Business-to-business sales strategies       1.00      1.00      1.00        10
#                                         CAD and 3D modeling       1.00      1.00      1.00         9
#                                     CAD and design software       1.00      1.00      1.00         7
#                                                CAD software       1.00      1.00      1.00        31
#                                    CAD software proficiency       1.00      1.00      1.00         8
#                                CAD/CAM software proficiency       1.00      1.00      1.00        14
#                                             CRM integration       1.00      1.00      1.00         6
#                                                CRM software       1.00      1.00      1.00        18
#                                          CRM software usage       1.00      1.00      1.00        14
#                                                         CSS       1.00      1.00      1.00        13
#                                       CSS for accessibility       1.00      1.00      1.00        12
#                                                        CSS,       1.00      1.00      1.00        27
#                                                    CSS, and       1.00      1.00      1.00        23
#                         Calendar and appointment management       1.00      1.00      1.00        14
#                                      Calendar and docketing       1.00      1.00      1.00         6
#                                         Calendar management       1.00      1.00      1.00        41
#                                      Call center operations       1.00      1.00      1.00         5
#                                          Campaign analytics       1.00      1.00      1.00        15
#                           Campaign effectiveness evaluation       1.00      1.00      1.00         7
#                                       Campaign optimization       1.00      1.00      1.00        18
#                                         Candidate screening       1.00      1.00      1.00         9
#                                            Canonicalization       1.00      1.00      1.00        13
#                                           Capacity planning       1.00      1.00      1.00        15
#                     Care coordination with healthcare teams       1.00      1.00      1.00         4
#                                               Care planning       1.00      1.00      1.00        11
#                                             Case management       1.00      1.00      1.00        33
#                                            Case preparation       1.00      1.00      1.00        14
#                                          Cash flow analysis       1.00      1.00      1.00         9
#                                               Cash handling       1.00      1.00      1.00        14
#                                  Catering and menu planning       1.00      1.00      1.00        18
#                            Ceremony and reception logistics       1.00      1.00      1.00        13
#                               Charge nurse responsibilities       1.00      1.00      1.00         6
#                                        Chemical engineering       1.00      1.00      1.00         8
#                                          Chemical reactions       1.00      1.00      1.00         8
#                                          Chemical synthesis       1.00      1.00      1.00        11
#                                               Child custody       1.00      1.00      1.00         9
#                                           Child custody law       1.00      1.00      1.00         6
#                                           Child development       1.00      1.00      1.00        13
#                                   Child protective services       1.00      1.00      1.00         9
#                                  Child psychology knowledge       1.00      1.00      1.00        12
#                      Child welfare policies and regulations       1.00      1.00      1.00         9
#                                  Chronic disease management       1.00      1.00      1.00        13
#                                            Circuit analysis       1.00      1.00      1.00        17
#                            Data analysis and interpretation       1.00      1.00      1.00         6
#                                 Data analysis and reporting       1.00      1.00      1.00        27
#                       Data analysis and visualization tools       1.00      1.00      1.00        14
#                                    Data analysis techniques       1.00      1.00      1.00        10
#                                         Data analysis tools       1.00      1.00      1.00        33
#                                              Data analytics       1.00      1.00      1.00        11
#                                    Data architecture design       1.00      1.00      1.00         5
#                           Data cleansing and transformation       1.00      1.00      1.00        26
#                                Data collection and analysis       1.00      1.00      1.00        62
#                          Data collection and interpretation       1.00      1.00      1.00        10
#                               Data collection and reporting       1.00      1.00      1.00         6
#                          Data encryption and access control       1.00      1.00      1.00         8
#                                                  Data entry       1.00      1.00      1.00         7
#                               Data entry accuracy and speed       1.00      1.00      1.00        18
#                                    Data entry and retrieval       1.00      1.00      1.00        12
#                                  Data governance principles       1.00      1.00      1.00        10
#                                            Data integration       1.00      1.00      1.00        11
#                                         Data interpretation       1.00      1.00      1.00        15
#                                                Data mapping       1.00      1.00      1.00        12
#                                              Data migration       1.00      1.00      1.00         9
#                                               Data modeling       1.00      1.00      1.00        67
#                                 Data modeling and reporting       1.00      1.00      1.00        14
#                                          Data preprocessing       1.00      1.00      1.00         8
#                             Data preprocessing and cleaning       1.00      1.00      1.00        23
#                                Data processing and analysis       1.00      1.00      1.00        10
#                               Data profiling and validation       1.00      1.00      1.00        10
#                     Data quality assessment and improvement       1.00      1.00      1.00        10
#                                      Data quality assurance       1.00      1.00      1.00        10
#                                               Data security       1.00      1.00      1.00        23
#             Data security and privacy regulations knowledge       1.00      1.00      1.00         8
#                                                  Data tools       1.00      1.00      1.00        10
#                                           Data verification       1.00      1.00      1.00        18
#                                          Data visualization       1.00      1.00      1.00        69
#                                    Data visualization tools       1.00      1.00      1.00        36
#                                            Data warehousing       1.00      1.00      1.00         3
#                                 Data-driven decision-making       1.00      1.00      1.00        24
#                            Database auditing and monitoring       1.00      1.00      1.00         8
#                                             Database design       1.00      1.00      1.00         9
#                             Database design and development       1.00      1.00      1.00         8
#                                        Database integration       1.00      1.00      1.00        15
#                                        Database maintenance       1.00      1.00      1.00         9
#                                         Database management       1.00      1.00      1.00        43
#                                 Database management systems       1.00      1.00      1.00        28
#                             Database querying and reporting       1.00      1.00      1.00        10
#                                  Database security measures       1.00      1.00      1.00         8
#                                           Database software       1.00      1.00      1.00        18
#                            Database tuning and optimization       1.00      1.00      1.00        23
#                               Debugging and troubleshooting       1.00      1.00      1.00        14
#                             Decor selection and arrangement       1.00      1.00      1.00         8
#                                            Deed preparation       1.00      1.00      1.00        12
#                                               Deep learning       1.00      1.00      1.00         8
#                               Defect reporting and tracking       1.00      1.00      1.00         7
#                                             Defect tracking       1.00      1.00      1.00        11
#                             Deliverability metrics analysis       1.00      1.00      1.00        13
#                                          Demand forecasting       1.00      1.00      1.00        45
#                                        Demonstrating skills       1.00      1.00      1.00         9
#                              Dental health program planning       1.00      1.00      1.00        10
#                                    Dental hygiene knowledge       1.00      1.00      1.00         5
#                                      Dental instrumentation       1.00      1.00      1.00         7
#                             Dental public health principles       1.00      1.00      1.00        10
#                                        Dentistry for horses       1.00      1.00      1.00         9
#                                       Testing methodologies       1.00      1.00      1.00        21
#                                            Therapy planning       1.00      1.00      1.00         7
#                                            Threat detection       1.00      1.00      1.00        11
#                                           Ticket management       1.00      1.00      1.00         6
#                                           Ticket resolution       1.00      1.00      1.00        11
#                                      Ticketing system usage       1.00      1.00      1.00        18
#                                             Time management       1.00      1.00      1.00        72
#                             Timeline and logistics planning       1.00      1.00      1.00        24
#                                           Timeline planning       1.00      1.00      1.00        13
#                                              Title searches       1.00      1.00      1.00        12
#                                    Trademark and patent law       1.00      1.00      1.00         7
#                               Traffic analysis and planning       1.00      1.00      1.00         6
#                                         Traffic engineering       1.00      1.00      1.00         7
#                                    Training and development       1.00      1.00      1.00        19
#                               Training material development       1.00      1.00      1.00        19
#                               Training program coordination       1.00      1.00      1.00        19
#                                Training program development       1.00      1.00      1.00         8
#                                               Transcription       1.00      1.00      1.00         6
#                                            Transfer pricing       1.00      1.00      1.00         5
#                              Transfer pricing documentation       1.00      1.00      1.00         5
#                                  Transportation engineering       1.00      1.00      1.00         6
#                                    Transportation logistics       1.00      1.00      1.00         7
#                                     Transportation planning       1.00      1.00      1.00        18
#                                           Trauma management       1.00      1.00      1.00        11
#                                        Trauma-informed care       1.00      1.00      1.00         8
#                                         Travel coordination       1.00      1.00      1.00        35
#                                         Treasury management       1.00      1.00      1.00         9
#                                          Treatment planning       1.00      1.00      1.00        21
#                                              Trend analysis       1.00      1.00      1.00        19
#                                        Trend identification       1.00      1.00      1.00        27
#                                       Triage and assessment       1.00      1.00      1.00        11
#                                               Trial support       1.00      1.00      1.00        21
#                                             Troubleshooting       1.00      1.00      1.00       115
#                             Troubleshooting and diagnostics       1.00      1.00      1.00         6
#                       Troubleshooting deliverability issues       1.00      1.00      1.00        13
#                     Troubleshooting wireless network issues       1.00      1.00      1.00        13
#                                                  Typography       1.00      1.00      1.00        32
#                                 Typography and color theory       1.00      1.00      1.00        41
#                     UI design principles and best practices       1.00      1.00      1.00        41
#                                                UI/UX design       1.00      1.00      1.00         3
#                                    UI/UX design 3D modeling       1.00      1.00      1.00         7
#                                                UX/UI design       1.00      1.00      1.00         6
#                                          UX/UI design tools       1.00      1.00      1.00        34
#                     Understanding of healthcare regulations       1.00      1.00      1.00         8
#                                   Urban design and planning       1.00      1.00      1.00         6
#                                              Urban planning       1.00      1.00      1.00        11
#                                        Usability evaluation       1.00      1.00      1.00         7
#                                           Usability testing       1.00      1.00      1.00        48
#                         Usability testing and user research       1.00      1.00      1.00        34
#                      Usability testing tools and techniques       1.00      1.00      1.00         7
#        Usability testing with individuals with disabilities       1.00      1.00      1.00        12
#                                         User authentication       1.00      1.00      1.00         6
#                                User behavior and psychology       1.00      1.00      1.00        51
#                                             User experience       1.00      1.00      1.00         8
#                                      User experience design       1.00      1.00      1.00        42
#                           User experience for accessibility       1.00      1.00      1.00        12
#                                    User experience strategy       1.00      1.00      1.00        10
#                                   User interface assessment       1.00      1.00      1.00         7
#                                       User interface design       1.00      1.00      1.00        70
#                                   User interface principles       1.00      1.00      1.00        13
#                                        User journey mapping       1.00      1.00      1.00        10
#                                                User manuals       1.00      1.00      1.00        14
#                                               User research       1.00      1.00      1.00        21
#                                       User research methods       1.00      1.00      1.00         6
#                                          User story writing       1.00      1.00      1.00         8
#                                                User testing       1.00      1.00      1.00         9
#                             User-centered design principles       1.00      1.00      1.00        34
#                                        Valuation techniques       1.00      1.00      1.00         9
#                                Vendor and sponsor relations       1.00      1.00      1.00         2
#                               Vendor and supplier relations       1.00      1.00      1.00        24
#                                           Vendor assessment       1.00      1.00      1.00        30
#                                        Vendor communication       1.00      1.00      1.00        10
#                                         Vendor coordination       1.00      1.00      1.00        67
#                                           Vendor management       1.00      1.00      1.00        47
#                                          Vendor negotiation       1.00      1.00      1.00        24
#                              Vendor outreach and engagement       1.00      1.00      1.00         6
#                                            Vendor relations       1.00      1.00      1.00        18
#                                             Venue selection       1.00      1.00      1.00        18
#                              Venue selection and management       1.00      1.00      1.00        24
#                                             Version control       1.00      1.00      1.00        31
#                                         Veterinary medicine       1.00      1.00      1.00         4
#                                 Virtualization technologies       1.00      1.00      1.00         9
#                                        Visual communication       1.00      1.00      1.00        20
#                                               Visual design       1.00      1.00      1.00         6
#                                    Visual design and layout       1.00      1.00      1.00        41
#                                               Visualization       1.00      1.00      1.00        11
#                                                      Vue.js       1.00      1.00      1.00        23
#                                    Vulnerability assessment       1.00      1.00      1.00        22
#            Vulnerability assessment and penetration testing       1.00      1.00      1.00        10
#                                      Vulnerability scanning       1.00      1.00      1.00         7
#                                        Warehouse management       1.00      1.00      1.00        13
#                                          Water conservation       1.00      1.00      1.00         7
#                            Water resource modeling software       1.00      1.00      1.00        11
#                                 Water resources engineering       1.00      1.00      1.00        11
#                                     Waterfall methodologies       1.00      1.00      1.00         9
#                                        Watershed management       1.00      1.00      1.00        11
#                                           Wealth management       1.00      1.00      1.00        13
#                                Wealth management strategies       1.00      1.00      1.00        11
#                                 Web accessibility standards       1.00      1.00      1.00        12
#                                               Web analytics       1.00      1.00      1.00         8
#                                 Web application development       1.00      1.00      1.00         6
#                                         Web design concepts       1.00      1.00      1.00        13
#                                       Web design principles       1.00      1.00      1.00         9
#                                Web performance optimization       1.00      1.00      1.00        19
#                                              Website audits       1.00      1.00      1.00         8
#                                      Website crawl analysis       1.00      1.00      1.00         5
#                                     Wedding design concepts       1.00      1.00      1.00         8
#                                           Wedding etiquette       1.00      1.00      1.00        31
#                                            Wedding planning       1.00      1.00      1.00        39
#                               Wi-Fi standards and protocols       1.00      1.00      1.00        13
#                                 Wireframing and prototyping       1.00      1.00      1.00        56
#                           Wireframing and prototyping tools       1.00      1.00      1.00        72
#                    Wireless network design and architecture       1.00      1.00      1.00        13
#                                         Wireless networking       1.00      1.00      1.00         6
#                                 Wireless security protocols       1.00      1.00      1.00        13
#                                         Workflow automation       1.00      1.00      1.00         6
#                                             Workflow design       1.00      1.00      1.00         8
#                Workplace discrimination and harassment laws       1.00      1.00      1.00         8
#                                        Workplace ergonomics       1.00      1.00      1.00         9
#                                    Writing research reports       1.00      1.00      1.00        10
#                                              Writing skills       1.00      1.00      1.00        12
#                                                XML sitemaps       1.00      1.00      1.00        13
#                                          Zoning regulations       1.00      1.00      1.00        17
#
#                                                   micro avg       1.00      1.00      1.00     23807
#                                                   macro avg       1.00      1.00      1.00     23807
#                                                weighted avg       1.00      1.00      1.00     23807
#                                                 samples avg       1.00      1.00      1.00     23807

# %% [markdown]
# ## Custom Exampels

# %%
importlib.reload(dc)
importlib.reload(te)
import pprint

def eval_sample_data(data):
    """Runs TF-IDF and Word2Vec models on a sample datapoint and prints the predicted skills.

    Args:
        data (dict): A dictionary containing the sample data.
    """
    sample_df = pd.DataFrame([data])
    sample_df['Preprocessed Job Description'] = sample_df['Job Description'].apply(lambda x: dc.preprocess_document(x, lemmatizer))
    sample_df['Preprocessed Responsibilities'] = sample_df['Responsibilities'].apply(lambda x: dc.preprocess_document(x, lemmatizer))

    sample_tfidf_X = dc.prepare_dataset(sample_df, tfidf_vectorizer, categorical_transformer, scaler, text_features, categorical_features, numerical_features)
    sample_w2v_X = te.embed_w2v_dataframe(sample_df, word_vectors, categorical_transformer, scaler, categorical_features, numerical_features)

    # Predict the skills required for the sample datapoint
    y_sample_pred_w2v = w2v_model.predict(sample_w2v_X)
    y_sample_pred_tfidf = tfidf_model.predict(sample_tfidf_X)

    # Convert the predicted skills back to their original labels
    w2v_pred_skills = mlb.inverse_transform(y_sample_pred_w2v)
    tfidf_pred_skills = mlb.inverse_transform(y_sample_pred_tfidf)
    pprint.pprint(data)
    print("Word2Vec Predicted Skills:", w2v_pred_skills)
    print("TF-IDF Predicted Skills:", tfidf_pred_skills)

# %%
importlib.reload(dc)
importlib.reload(te)

# Define a sample datapoint
data_points = [
{
    'Job Description': 'Family Law Attorneys deal with legal matters related to relationships.',
    'Responsibilities': 'Specialize in family law matters, such as divorce, child custody, and adoption.',
    'Qualifications': 'PhD',
    'Work Type': 'Full-Time',
    'Preference': 'Female',
    'Job Title': 'Litigation Attorney',
    'Role': 'Family Law Attorney',
    'Company Size': 10000,
},
{
    'Job Description': 'Urgently hiring a educational specialist in early-childhood development and special education curriculums.',
    'Responsibilities': 'Develop and implement educational programs for children with special needs.',
    'Qualifications': 'Masters',
    'Work Type': 'Part-Time',
    'Preference': 'Both',
    'Job Title': 'Special Education Teacher',
    'Role': 'Educational Specialist',
    'Company Size': 500,
}]

for data in data_points:
    eval_sample_data(data)
    print('\n')
# Out:
# {'Company Size': 10000,
#  'Job Description': 'Family Law Attorneys deal with legal matters related to '
#                     'relationships.',
#  'Job Title': 'Litigation Attorney',
#  'Preference': 'Female',
#  'Qualifications': 'PhD',
#  'Responsibilities': 'Specialize in family law matters, such as divorce, child '
#                      'custody, and adoption.',
#  'Role': 'Family Law Attorney',
#  'Work Type': 'Full-Time'}
# Word2Vec Predicted Skills: [('Court representation', 'Family law', 'Mediation')]
# TF-IDF Predicted Skills: [()]
#
#
# {'Company Size': 500,
#  'Job Description': 'Urgently hiring a educational specialist in '
#                     'early-childhood development and special education '
#                     'curriculums.',
#  'Job Title': 'Special Education Teacher',
#  'Preference': 'Both',
#  'Qualifications': 'Masters',
#  'Responsibilities': 'Develop and implement educational programs for children '
#                      'with special needs.',
#  'Role': 'Educational Specialist',
#  'Work Type': 'Part-Time'}
# Word2Vec Predicted Skills: [()]
# TF-IDF Predicted Skills: [()]
